# %%
using DataFrames, Random
Random.seed!(1)
df = DataFrame(rand(1000, 100))
# Out:
# 1000×100 DataFrame. Omitted printing of 95 columns
# │ Row  │ x1         │ x2        │ x3         │ x4        │ x5       │
# │      │ Float64    │ Float64   │ Float64    │ Float64   │ Float64  │
# ├──────┼────────────┼───────────┼────────────┼───────────┼──────────┤
# │ 1    │ 0.236033   │ 0.690796  │ 0.916526   │ 0.234869  │ 0.110848 │
# │ 2    │ 0.346517   │ 0.790699  │ 0.665206   │ 0.660458  │ 0.127127 │
# │ 3    │ 0.312707   │ 0.979872  │ 0.850925   │ 0.821268  │ 0.242334 │
# │ 4    │ 0.00790928 │ 0.267909  │ 0.768654   │ 0.55841   │ 0.130459 │
# │ 5    │ 0.488613   │ 0.712707  │ 0.854629   │ 0.955296  │ 0.358845 │
# │ 6    │ 0.210968   │ 0.291492  │ 0.106008   │ 0.220847  │ 0.338698 │
# │ 7    │ 0.951916   │ 0.0198805 │ 0.00631802 │ 0.418398  │ 0.729752 │
# │ 8    │ 0.999905   │ 0.371177  │ 0.0425443  │ 0.236362  │ 0.908045 │
# │ 9    │ 0.251662   │ 0.550494  │ 0.335658   │ 0.640743  │ 0.406632 │
# │ 10   │ 0.986666   │ 0.793547  │ 0.137559   │ 0.0385452 │ 0.865191 │
# ⋮
# ...

# %%
nrow(df), ncol(df), size(df)
# Out:
# (1000, 100, (1000, 100))

# %%
describe(df[:, 1:3])
# Out:
# 3×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable │ mean     │ min         │ median   │ max      │ nunique │
# │     │ Symbol   │ Float64  │ Float64     │ Float64  │ Float64  │ Nothing │
# ├─────┼──────────┼──────────┼─────────────┼──────────┼──────────┼─────────┤
# │ 1   │ x1       │ 0.488644 │ 0.000576032 │ 0.476469 │ 0.999954 │         │
# │ 2   │ x2       │ 0.509981 │ 0.00288489  │ 0.512756 │ 0.997931 │         │
# │ 3   │ x3       │ 0.508213 │ 0.00109271  │ 0.535656 │ 0.999943 │         │

# %%
filter(x -> occursin(r"1[13579]$", String(x[:variable])), describe(df))
# Out:
# 5×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable │ mean     │ min         │ median   │ max      │ nunique │
# │     │ Symbol   │ Float64  │ Float64     │ Float64  │ Float64  │ Nothing │
# ├─────┼──────────┼──────────┼─────────────┼──────────┼──────────┼─────────┤
# │ 1   │ x11      │ 0.504936 │ 0.000827051 │ 0.520504 │ 0.999032 │         │
# │ 2   │ x13      │ 0.500973 │ 0.00115659  │ 0.505368 │ 0.998485 │         │
# │ 3   │ x15      │ 0.510734 │ 0.000727684 │ 0.531603 │ 0.999445 │         │
# │ 4   │ x17      │ 0.503683 │ 0.000417392 │ 0.503093 │ 0.999452 │         │
# │ 5   │ x19      │ 0.505176 │ 0.0010843   │ 0.515455 │ 0.999975 │         │

# %%
desc = describe(df)
# Out:
# 100×8 DataFrame. Omitted printing of 2 columns
# │ Row │ variable │ mean     │ min         │ median   │ max      │ nunique │
# │     │ Symbol   │ Float64  │ Float64     │ Float64  │ Float64  │ Nothing │
# ├─────┼──────────┼──────────┼─────────────┼──────────┼──────────┼─────────┤
# │ 1   │ x1       │ 0.488644 │ 0.000576032 │ 0.476469 │ 0.999954 │         │
# │ 2   │ x2       │ 0.509981 │ 0.00288489  │ 0.512756 │ 0.997931 │         │
# │ 3   │ x3       │ 0.508213 │ 0.00109271  │ 0.535656 │ 0.999943 │         │
# │ 4   │ x4       │ 0.493011 │ 0.00011805  │ 0.488826 │ 0.998477 │         │
# │ 5   │ x5       │ 0.496312 │ 0.00161943  │ 0.485092 │ 0.999661 │         │
# │ 6   │ x6       │ 0.493533 │ 0.00190835  │ 0.490155 │ 0.999983 │         │
# │ 7   │ x7       │ 0.510114 │ 0.000141881 │ 0.516738 │ 0.999389 │         │
# │ 8   │ x8       │ 0.516298 │ 0.00029478  │ 0.530275 │ 0.99985  │         │
# │ 9   │ x9       │ 0.515694 │ 0.00127138  │ 0.515063 │ 0.999262 │         │
# ...

# %%
first(df, 6)
# Out:
# 6×100 DataFrame. Omitted printing of 94 columns
# │ Row │ x1         │ x2       │ x3       │ x4       │ x5       │ x6       │
# │     │ Float64    │ Float64  │ Float64  │ Float64  │ Float64  │ Float64  │
# ├─────┼────────────┼──────────┼──────────┼──────────┼──────────┼──────────┤
# │ 1   │ 0.236033   │ 0.690796 │ 0.916526 │ 0.234869 │ 0.110848 │ 0.269245 │
# │ 2   │ 0.346517   │ 0.790699 │ 0.665206 │ 0.660458 │ 0.127127 │ 0.173602 │
# │ 3   │ 0.312707   │ 0.979872 │ 0.850925 │ 0.821268 │ 0.242334 │ 0.661161 │
# │ 4   │ 0.00790928 │ 0.267909 │ 0.768654 │ 0.55841  │ 0.130459 │ 0.924226 │
# │ 5   │ 0.488613   │ 0.712707 │ 0.854629 │ 0.955296 │ 0.358845 │ 0.48006  │
# │ 6   │ 0.210968   │ 0.291492 │ 0.106008 │ 0.220847 │ 0.338698 │ 0.838496 │

# %%
last(df, 6)
# Out:
# 6×100 DataFrame. Omitted printing of 94 columns
# │ Row │ x1       │ x2        │ x3       │ x4       │ x5       │ x6       │
# │     │ Float64  │ Float64   │ Float64  │ Float64  │ Float64  │ Float64  │
# ├─────┼──────────┼───────────┼──────────┼──────────┼──────────┼──────────┤
# │ 1   │ 0.291905 │ 0.0284643 │ 0.212544 │ 0.2994   │ 0.23854  │ 0.69212  │
# │ 2   │ 0.519958 │ 0.466166  │ 0.392835 │ 0.596408 │ 0.863579 │ 0.41959  │
# │ 3   │ 0.167934 │ 0.468282  │ 0.639171 │ 0.365032 │ 0.637664 │ 0.88812  │
# │ 4   │ 0.641344 │ 0.685095  │ 0.109315 │ 0.68066  │ 0.883736 │ 0.24411  │
# │ 5   │ 0.592039 │ 0.707274  │ 0.860689 │ 0.74508  │ 0.825192 │ 0.867586 │
# │ 6   │ 0.730528 │ 0.813099  │ 0.636953 │ 0.150466 │ 0.344309 │ 0.20553  │

# %%
names(df)
# Out:
# 100-element Array{Symbol,1}:
#  :x1
#  :x2
#  :x3
#  :x4
#  :x5
#  :x6
#  :x7
#  :x8
#  :x9
#  :x10
#  :x11
#  :x12
#  :x13
#  ⋮
#  :x89
#  :x90
#  :x91
#  :x92
#  :x93
#  :x94
#  :x95
#  :x96
#  :x97
#  :x98
#  :x99
#  :x100

# %%
eltypes(df)
# Out:
# 100-element Array{DataType,1}:
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  ⋮
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
